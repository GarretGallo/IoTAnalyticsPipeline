-- %% [markdown]
-- #### The Purpose of this Notebook is to Automatically Update Pull in New Data

-- %%
COPY INTO gasmonitordata.bronze.ingesteddata
FROM 's3://gasmonitorsbronze/topics/'
FILEFORMAT = JSON
FORMAT_OPTIONS ('inferSchema' = 'true')
